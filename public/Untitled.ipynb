# %%
import json

# %%
with open('processed_gundeaths_data.json', 'r') as file:
    data = json.load(file)

# Extract city names
city_names = [city['key'] for city in data['cities']]

# Print the city names
for city_name in city_names:
    print(city_name)
# Out:
# Anchorage_Alaska
# Chugiak_Alaska
# Cooper Landing_Alaska
# Delta Junction_Alaska
# Fairbanks_Alaska
# Fairview_Alaska
# Fort Richardson_Alaska
# Joint Base Elmendorf-Richardson_Alaska
# King Salmon_Alaska
# Kodiak_Alaska
# Manokotak_Alaska
# Mountain Village_Alaska
# Sitka_Alaska
# Soldotna_Alaska
# Sutton_Alaska
# Tununak_Alaska
# Wasilla_Alaska
# Albertville_Alabama
# Auburn_Alabama
# Autauga County_Alabama
# Bessemer_Alabama
# Birmingham_Alabama
# Black Pond_Alabama
# Brierfield_Alabama
# Calera_Alabama
# Carrollton_Alabama
# Cherokee County_Alabama
# Cleburne County_Alabama
# Crawford_Alabama
# Cullman_Alabama
# Decatur_Alabama
# Dothan_Alabama
# Elmore County_Alabama
# Enterprise_Alabama
# Eufaula_Alabama
# Fairfield_Alabama
# Fairview_Alabama
# Florence_Alabama
# Fyffe_Alabama
# Gadsden_Alabama
# Gardendale_Alabama
# Geraldine_Alabama
# Grand Bay_Alabama
# Gurley_Alabama
# Heflin_Alabama
# Homewood_Alabama
# Hoover_Alabama
# Huntsville_Alabama
# Hurtsboro_Alabama
# ...
